# %%
import cv2
import time
import IPython.display
import PIL.Image

# Load a photo of Donald Trump
trump1 = cv2.imread('images/axolotl.jpg')

# Convert the image space from BGR (Blue, Green, Red) to RGB

# Show the image of Trump
# CHALLENGE: Use the openCV documentation to draw red eyes on Donald Trump
# https://docs.opencv.org/3.1.0/dc/da5/tutorial_py_drawing_functions.html
"""
name = input("What is your name? ")
print ("\nHey there " + name + "!")
time.sleep(2)
creature = input("\nWhat is your favorite sea creature? ")
print ("\nI like Axolotls better than " + creature + "s, but that's just my opinion.")
time.sleep(2)
print ("\nLet's load a photo of an Axolotl using openCV. We can switch it for a " + creature + " later....")
time.sleep(2)
print ("\nUse your Trump code to help you figure it out. The image is called: axolotl.jpg")
trump = cv2.imread('images/axolotol.jpg')
trump = cv2.imread('images/trump.jpg')

# Convert the image space from BGR (Blue, Green, Red) to RGB
trump = cv2.cvtColor(trump, cv2.COLOR_BGR2RGB)

# Resize Trump
trump = cv2.resize(trump,(800,450))
# Put your code under here. You can delete the intro if it's annoying you ;)
"""
cv2.ellipse(trump1,(350,170),(30,20),0,10,190,255,-1)
cv2.ellipse(trump1,(350,190),(25,15),0,0,360,255,-1)
cv2.ellipse(trump1,(350,210),(20,10),0,0,360,255,-1)
cv2.ellipse(trump1,(350,230),(15,10),0,0,360,255,-1)
# Show the image of Trump
IPython.display.display(PIL.Image.fromarray(trump1))
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x9EB1BB10>

# %%
ax = cv2.imread('images/axolotol.jpg')
IPython.display.display(PIL.Image.fromarray(ax))
