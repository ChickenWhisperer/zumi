# %%
import cv2
import IPython.display
import PIL.Image

# Load a photo of Donald Trump
trump = cv2.imread('images/trump.jpg')

# Convert the image space from BGR (Blue, Green, Red) to RGB
trump = cv2.cvtColor(trump, cv2.COLOR_BGR2RGB)

# Resize Trump
trump = cv2.resize(trump,(800,450))
# Draw a diagonal blue line with thickness of 5 px
cv2.ellipse(trump,(350,170),(30,20),0,0,360,255,-1)
cv2.ellipse(trump,(430,170),(30,20),0,0,360,255,-1)
cv2.ellipse(trump,(350,170),(20,20),0,0,360,100,-1)
cv2.ellipse(trump,(430,170),(20,20),0,0,360,100,-1)
cv2.ellipse(trump,(350,170),(10,10),0,0,360,0,-1)
cv2.ellipse(trump,(430,170),(10,10),0,0,360,0,-1)
# Show the image of Trump
IPython.display.display(PIL.Image.fromarray(trump))

# CHALLENGE: Use the openCV documentation to draw red eyes on Donald Trump
# https://docs.opencv.org/3.1.0/dc/da5/tutorial_py_drawing_functions.html
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x9EC63FF0>
